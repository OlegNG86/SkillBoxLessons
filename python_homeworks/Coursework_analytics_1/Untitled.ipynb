# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\OLEGWORKPC\Downloads\Копия Мат. отчёт 24.01.20 (1).xlsx', index_col=None, header=None)

# %%
df.columns = df.loc[5]

# %%
df[6:]
# Out:
# 5    NaN                                         Ном. номер  NaN  \
# 6    NaN                                                NaN  NaN
# 7    NaN                                                NaN  NaN
# 8    NaN                                        БП-00006976  NaN
# 9    NaN                                        БП-00007333  NaN
# 10   NaN                                        БП-00006977  NaN
# 11   NaN                                        БП-00006982  NaN
# 12   NaN                                        БП-00006966  NaN
# 13   NaN                                        БП-00006978  NaN
# 14   NaN                                        БП-00006979  NaN
# 15   NaN                                        БП-00006980  NaN
# 16   NaN                                        БП-00006981  NaN
# 17   NaN                                        БП-00006747  NaN
# 18   NaN                                        БП-00007334  NaN
# ...
